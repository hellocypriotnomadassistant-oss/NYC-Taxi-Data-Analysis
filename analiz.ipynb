# %%
import pandas as pd

# Veri setini yükle (Klasör içindeki CSV dosyasının adını kullanıyoruz)
df = pd.read_csv('iyPaw9UGRD-F_oU318b6Cg_f07cadf326314912bcac2fea48e87ff1_2017_Yellow_Taxi_Trip_Data.csv')

# İlk 5 satırı görüntüle
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  str
#  3   tpep_dropoff_datetime  22699 non-null  str
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  str
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
#  14  tip_amount             22699 non-null  float64
# ...

# %%
credit_card = df[df['payment_type'] == 1]

# %%
credit_card.groupby('passenger_count')['tip_amount'].mean()

# %% [markdown]
# After analyzing the NYC taxi data, I found that the two most important variables for building a predictive model for trip fares are trip_distance and total_amount. Additionally, the payment_type significantly impacts the tip_amount recorded in the data. These variables provide the strongest insights for forecasting and business decisions.
